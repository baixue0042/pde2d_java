# %%
import os
filename = os.path.expanduser('~/Documents/data_working/RoiSet.zip')
from read_roi import read_roi_zip

rois = read_roi_zip(filename)

# %%
rois.keys()
# Out:
# odict_keys(['0001-0001-0096', '0001-0002-0082', '0001-0003-0124', '0001-0004-0121', '0001-0005-0150', '0001-0006-0207', '0001-0007-0244', '0001-0008-0247', '0001-0009-0327', '0001-0010-0297', '0001-0011-0310', '0001-0012-0343', '0001-0013-0350', '0002-0014-0097', '0002-0015-0081', 'lala', '0002-0017-0121', '0002-0018-0149', '0002-0019-0206', '0002-0020-0243', '0002-0021-0246', '0002-0022-0328', '0002-0023-0310', '0003-0024-0098', '0003-0025-0081', '0003-0026-0126', '0003-0027-0121', '0003-0028-0148', '0003-0029-0205', '0003-0030-0242', '0003-0031-0245', '0003-0032-0330', '0003-0033-0311', '0004-0034-0107', '0004-0035-0117', '0004-0036-0121', '0004-0037-0204', '0004-0038-0245', '0004-0039-0243', '0004-0040-0331', '0004-0041-0311', '0005-0042-0106', '0005-0043-0118', '0005-0044-0119', '0005-0045-0202', '0005-0046-0245', '0005-0047-0245', '0005-0048-0332', '0005-0049-0311', '0006-0050-0100', '0006-0051-0117', '0006-0052-0118', '0006-0053-0148', '0006-0054-0202', '0006-0055-0243', '0006-
# ...

# %%
rois['0135-0989-0114']
# Out:
# {'n': 118,
#  'name': '0135-0989-0114',
#  'position': 135,
#  'type': 'traced',
#  'x': [212,
#   217,
#   217,
#   221,
#   221,
#   224,
#   224,
#   227,
#   227,
#   230,
#   230,
#   233,
#   233,
#   236,
#   236,
#   238,
#   238,
#   240,
#   240,
#   242,
#   242,
#   243,
#   243,
#   244,
#   244,
#   245,
#   245,
#   246,
#   246,
#   247,
#   247,
#   248,
#   248,
#   249,
#   249,
#   250,
#   250,
#   249,
#   249,
#   248,
#   248,
#   247,
#   247,
#   246,
#   246,
#   244,
#   244,
#   235,
#   235,
#   232,
#   232,
#   229,
#   229,
#   222,
#   222,
#   219,
#   219,
#   213,
#   213,
#   211,
#   211,
#   207,
#   207,
#   202,
#   202,
#   200,
#   200,
#   198,
#   198,
#   197,
#   197,
#   196,
#   196,
#   195,
#   195,
#   194,
#   194,
#   193,
#   193,
#   192,
#   192,
#   191,
#   191,
#   190,
#   190,
#   189,
#   189,
#   188,
#   188,
#   187,
#   187,
#   186,
#   186,
#   185,
#   185,
#   184,
#   184,
#   185,
#   185,
#   186,
#   186,
# ...
